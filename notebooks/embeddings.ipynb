# %% [markdown]
# # Analyzing the embeddings
#
# This notebook pretends to analyze the output of the get_embeddings script

# %%
# Library imports
import os

import pandas as pd
import numpy as np
from datasets import load_dataset
import matplotlib.pyplot as plt
from sentence_transformers import util

# %%
# Setting up environment variables
os.environ['HF_HOME'] = '$HOME/tesis/00_src/run/models'

# %%
# Global variables
DATA_PATH = '/home/rgarcia/tesis/00_src/normativity-rag/outs/csv_multi_qa_bert'
DATASET_CSV = '/home/rgarcia/tesis/00_src/normativity-rag/outs/dataset/multi_qa_distilbert'
DATASET_NAME = 'Rivert97/ug-normativity'

# Other Variables
filename = 'ley-organica-de-la-universidad-de-guanajuato'
#filename = 'estatuto-organico-de-la-universidad-de-guanajuato'
#filename = 'reglamento-de-mecanismos-alternos-de-solucion-de-controversias-ug-ugto'

# %%
# Loading the data
embeddings = pd.read_csv(os.path.join(DATA_PATH, f"{filename}_embeddings.csv"), sep=',')
data = pd.read_csv(os.path.join(DATA_PATH, f"{filename}.csv"), sep=',')

# %%
data.head()
# Out:
#                                   document_name  \
# 0  ley-organica-de-la-universidad-de-guanajuato
# 1  ley-organica-de-la-universidad-de-guanajuato
# 2  ley-organica-de-la-universidad-de-guanajuato
# 3  ley-organica-de-la-universidad-de-guanajuato
# 4  ley-organica-de-la-universidad-de-guanajuato
#
#                                                title  \
# 0       LEY ORGÁNICA DE LA UNIVERSIDAD DE GUANAJUATO
# 1                         I. Del proceso legislativo
# 2                         II. Trabajo de la comisión
# 3  III. Fundamento constitucional de la materia e...
# 4                    IV. Valoración de la iniciativa
#
#                                                 path  \
# 0  /root/LEY ORGÁNICA DE LA UNIVERSIDAD DE GUANAJ...
# 1   /root/D I C T A M E N/I. Del proceso legislativo
# 2   /root/D I C T A M E N/II. Trabajo de la comisión
# 3  /root/D I C T A M E N/III. Fundamento constitu...
# 4  /root/D I C T A M E N/IV. Valoración de la ini...
#
#                                               parent  \
# 0       LEY ORGÁNICA DE LA UNIVERSIDAD DE GUANAJUATO
# 1                         I. Del proceso legislativo
# 2                         II. Trabajo de la comisión
# 3  III. Fundamento constitucional de la materia e...
# 4                    IV. Valoración de la iniciativa
#
#                                            sentences
# 0  DICTAMEN DE LA COMISIÓN DE GOBERNACIÓN Y PUNTO...
# 1  Antecedentes 1. En el ejercicio de la facultad...
# 2  Quienes integramos esta Comisión de Gobernació...
# 3  La iniciativa en estudio tiene sustento en lo ...
# 4  Para el desarrollo del presente análisis y dic...

# %%
embeddings.head()
# Out:
#           0         1         2         3         4         5         6  \
# 0 -0.434363  0.424539 -0.171204  0.280679  0.084210 -0.364482 -0.139645
# 1 -0.340021  0.466494 -0.146184  0.222079 -0.018522 -0.529120  0.176575
# 2 -0.341579  0.590322 -0.110237  0.059490  0.066331 -0.326537  0.184488
# 3 -0.381004  0.225741 -0.225909  0.325977 -0.021064 -0.441375  0.112813
# 4 -0.262034  0.157724 -0.129995  0.084295  0.154342 -0.366713 -0.087052
#
#           7         8         9  ...       758       759       760       761  \
# 0  0.393045  0.249619  0.353894  ... -0.350286  0.250727 -0.060458  0.294011
# 1  0.349465 -0.047715  0.200768  ... -0.593357  0.082471  0.325703  0.087460
# 2  0.152167 -0.133803  0.068266  ... -0.616501  0.070029 -0.014567  0.035515
# 3  0.072671 -0.171903  0.222488  ... -0.530421  0.255400 -0.052161  0.187710
# 4  0.254177 -0.211838  0.157856  ... -0.648166  0.219369  0.036493 -0.038319
#
#         762       763       764       765       766       767
# 0  0.065321  0.212353 -0.084945 -0.317657 -0.390467 -0.107246
# 1 -0.002500  0.071658 -0.157353 -0.205331 -0.383321  0.034862
# 2  0.095475  0.049782 -0.175534 -0.630877 -0.394585  0.038051
# 3  0.071661  0.082669 -0.157674 -0.295486 -0.364604  0.042931
# 4  0.029621 -0.081126 -0.087598 -0.472696 -0.229321 -0.158967
#
# [5 rows x 768 columns]

# %%
# Loading questions dataset
dataset = load_dataset(DATASET_NAME)
dataset = dataset['train']
dataset = dataset.filter(lambda row: row['title'] == filename)

questions_embeddings = pd.read_csv(os.path.join(DATASET_CSV, f"{filename}.csv"), sep=',', index_col=0)

# %%
dataset
# Out:
# Dataset({
#     features: ['id', 'title', 'context', 'additional_context', 'question', 'answers'],
#     num_rows: 114
# })

# %%
questions_embeddings
# Out:
#                                          0         1         2         3  \
# 81e729afa369916be4d4db99f9c1817c -0.241163  0.134452 -0.406884  0.027158
# 28738544e42b076370fc813c5711852a -0.353499  0.290611 -0.296301  0.106464
# 948cb616a68fe33024da19654b56a0b1 -0.077598  0.016400 -0.392371  0.015349
# e80f3ca8fb8791ca480ee02bf9250484 -0.054256  0.148170 -0.450834  0.325257
# c1ca177b00aeae41aa361c243e612a9d -0.252703 -0.193184 -0.384962  0.309104
# ...                                    ...       ...       ...       ...
# 6c0faf36d205191964ae5a1582e1c804 -0.166262  0.144691 -0.380705  0.180002
# d2679597685558ef9c1a0158452ef204 -0.457035 -0.044209 -0.320744  0.160276
# d40c2da6c4422f4732ebba0abcf8b3b7 -0.340062  0.061185 -0.334158  0.093446
# 0cb3797bf6238e3135b4afb1157fd65e -0.149213  0.200428 -0.349729  0.252843
# d30fa2feedbaac7656503ea73d7f8ff2 -0.357425 -0.284368 -0.290802 -0.042259
#
#                                          4         5         6         7  \
# 81e729afa369916be4d4db99f9c1817c  0.085603 -0.483060  0.077630  0.043037
# 28738544e42b076370fc813c5711852a  0.137439 -0.704990  0.105013  0.176509
# 948cb616a68fe33024da19654b56a0b1  0.138048 -0.206328  0.224212 -0.187583
# e80f3ca8fb8791ca480ee02bf9250484  0.108277 -0.137115  0.209664 -0.146938
# c1ca177b00aeae41aa361c243e612a9d  0.024936 -0.346492 -0.082598 -0.207490
# ...                                    ...       ...       ...       ...
# 6c0faf36d205191964ae5a1582e1c804  0.164794 -0.332864  0.345870 -0.206776
# d2679597685558ef9c1a0158452ef204  0.004930 -0.215657  0.265613 -0.443395
# d40c2da6c4422f4732ebba0abcf8b3b7  0.048074 -0.152664  0.139678 -0.318238
# 0cb3797bf6238e3135b4afb1157fd65e  0.022970 -0.442764  0.493335 -0.197639
# [114 rows x 768 columns]

# %% [markdown]
# # Data Analysis

# %%
# For each question find its chunk
questions = []

for question in dataset:
    tmp_question = {
        'question': question,
        'question_embeddings': questions_embeddings.loc[question['id']].values,
        'chunk_idx': None,
        'chunk': None,
        'chunk_embeddings': None,
    }

    for chunk_idx, chunk in data.iterrows():
        if chunk['path'].lower().endswith(question['context'].lower().strip()):
            tmp_question['chunk_idx'] = chunk_idx
            tmp_question['chunk'] = chunk
            tmp_question['chunk_embeddings'] = embeddings.loc[chunk_idx].values
            break

    if tmp_question['chunk_idx'] is not None:
        questions.append(tmp_question)

# %%
# Analyzing distances between questions and its chunks
distances = []
for question in questions:
    score = util.dot_score(question['question_embeddings'], question['chunk_embeddings'])
    distances.append(score[0][0])

plt.figure()
plt.title("Distance from questions to its chunks")
plt.boxplot(distances)
print("Min: ", min(distances))
print("Max: ", max(distances))
print("Mean: ", np.mean(distances))
# Out:
# Min:  tensor(16.8300, dtype=torch.float64)
# Max:  tensor(32.4599, dtype=torch.float64)
# Mean:  27.199482506113053

# %%
# Analyzing distance from each question to its K neighbors
k = 5
top_k_distances = []
top_k_distances_mean = []
top_k_embeddings_idx = {}
for question in questions:
    scores = util.dot_score(question['question_embeddings'], embeddings.values)[0].tolist()
    doc_score_pairs = list(zip(data.index.tolist(), scores))

    doc_score_pairs = sorted(doc_score_pairs, key=lambda x: x[1], reverse=True)

    dist = [d[1] for d in doc_score_pairs[:k]]
    idx = [d[0] for d in doc_score_pairs[:k]]

    top_k_distances.extend(dist)
    top_k_distances_mean.append(np.mean(dist))
    top_k_embeddings_idx[question['question']['id']] = idx

plt.figure()
plt.title(f"Distance from question to {k} nearest neighbors")
plt.boxplot((top_k_distances, top_k_distances_mean), tick_labels=[f'Top {k}', f'Top {k} mean'])
print(f"Top {k}")
print("Min: ", min(top_k_distances))
print("Max: ", max(top_k_distances))
print("Mean: ", np.mean(top_k_distances))
print(f"Top {k} mean")
print("Min: ", min(top_k_distances_mean))
print("Max: ", max(top_k_distances_mean))
print("Mean: ", np.mean(top_k_distances_mean))
# Out:
# Top 5
# Min:  19.92078241364458
# Max:  33.59888788621709
# Mean:  26.599456791037166
# Top 5 mean
# Min:  20.764047416668802
# Max:  30.831347754182367
# Mean:  26.59945679103717

# %%
# Analyzing percentaje of answers present in K nearest neighbors
count_in_top_k = 0
for question in questions:
    top_k_idx = top_k_embeddings_idx[question['question']['id']]
    if question['chunk_idx'] in top_k_idx:
        count_in_top_k += 1

print(f"% of presence in top {k}: {count_in_top_k/len(questions)}")
# Out:
# ¿Cuál es el fundamento legal que sustenta la Ley Orgánica?
# 78                                ARTÍCULO SEGUNDO
# 8                                       Artículo 2
# 75                                     Artículo 62
# 0     LEY ORGÁNICA DE LA UNIVERSIDAD DE GUANAJUATO
# 64                                     Artículo 57
# Name: parent, dtype: object
# ---------
# La Universidad de Guanajuato ¿es autónoma?
# 9           Artículo 3
# 68         Artículo 60
# 90      Artículo Sexto
# 78    ARTÍCULO SEGUNDO
# 50         Artículo 43
# Name: parent, dtype: object
# ---------
# ¿Cuáles son las funciones escenciales de la universidad?
# 11     Artículo 5
# 53    Artículo 46
# 43    Artículo 37
# 60    Artículo 53
# 54    Artículo 47
# Name: parent, dtype: object
# ---------
# ¿Cuál es el objetivo del Plan de Desarrollo Institucional?
# 13     Artículo 7
# 61    Artículo 54
# 55    Artículo 48
# 12     Artículo 6
# 75    Artículo 62
# Name: parent, dtype: object
# ---------
# ¿Quienes integran la comunidad universitaria?
# 29         Artículo 23
# 65         Artículo 58
# 60         Artículo 53
# 14          Artículo 8
# 83    ARTÍCULO SÉPTIMO
# Name: parent, dtype: object
# ---------
# ¿Quienes conforman al personal académico?
# 59    Artículo 52
# 76    Artículo 63
# 14     Artículo 8
# 61    Artículo 54
# 64    Artículo 57
# Name: parent, dtype: object
# ---------
# ¿Cuáles son los subsistemas en que se divide la Universidad?
# 17    Artículo 11
# 19    Artículo 13
# 11     Artículo 5
# 15     Artículo 9
# 54    Artículo 47
# Name: parent, dtype: object
# ---------
# ¿Cómo se integra el nivel superior?
# 20    Artículo 14
# 18    Artículo 12
# 39    Artículo 33
# 41    Artículo 35
# 42    Artículo 36
# Name: parent, dtype: object
# ---------
# ¿Qué es un Campus?
# 19    Artículo 13
# 29    Artículo 23
# 31    Artículo 25
# 15     Artículo 9
# 30    Artículo 24
# Name: parent, dtype: object
# ---------
# ¿Qué es una División?
# 33                                          Artículo 27
# 34                                          Artículo 28
# 67    CAPÍTULO II ÓRGANO INTERNO DE CONTROL DE LA UN...
# 36                                          Artículo 30
# 19                                          Artículo 13
# Name: parent, dtype: object
# ---------
# ¿Cómo se integra el nivel medio superior?
# 20    Artículo 14
# 18    Artículo 12
# 39    Artículo 33
# 41    Artículo 35
# 42    Artículo 36
# Name: parent, dtype: object
# ---------
# ¿Quién preside el Consejo General Unviersitario?
# 21    Artículo 15
# 28    Artículo 22
# 25    Artículo 19
# 51    Artículo 44
# 50    Artículo 43
# Name: parent, dtype: object
# ---------
# ¿Cuántos profesores del Colegio del Nivel Medio Superior conforman el Consejo General Universitario?
# 21    Artículo 15
# 58    Artículo 51
# 39    Artículo 33
# 64    Artículo 57
# 18    Artículo 12
# Name: parent, dtype: object
# ---------
# ¿Cuántos alumnos del Colegio de Nivel Medio Superior conforman el Consejo General Universitario?
# 18         Artículo 12
# 21         Artículo 15
# 41         Artículo 35
# 39         Artículo 33
# 83    ARTÍCULO SÉPTIMO
# Name: parent, dtype: object
# ---------
# ¿Cuáles son los requisitos que deben cumplir los miembros de la junta directiva?
# 23         Artículo 17
# 24         Artículo 18
# 89     Artículo Quinto
# 50         Artículo 43
# 79    ARTÍCULO TERCERO
# Name: parent, dtype: object
# ---------
# ¿Cuánto tiempo están en el cargo los integrantes de la Junta Directiva?
# 23         Artículo 17
# 89     Artículo Quinto
# 47         Artículo 41
# 79    ARTÍCULO TERCERO
# 83    ARTÍCULO SÉPTIMO
# Name: parent, dtype: object
# ---------
# ¿Los miembros de la Junta Directiva reciben un pago?
# 23         Artículo 17
# 24         Artículo 18
# 47         Artículo 41
# 85    Artículo Primero
# 77    ARTÍCULO PRIMERO
# Name: parent, dtype: object
# ---------
# ¿Quién designa al Rector General?
# 25    Artículo 19
# 28    Artículo 22
# 31    Artículo 25
# 24    Artículo 18
# 27    Artículo 21
# Name: parent, dtype: object
# ---------
# ¿Quién elabora el reglamento interno de la Junta Directiva?
# 23        Artículo 17
# 24        Artículo 18
# 71    Artículo 61 Bis
# 88    Artículo Cuarto
# 76        Artículo 63
# Name: parent, dtype: object
# ---------
# ¿Cuáles son las funciones de la Junta Directiva?
# 23        Artículo 17
# 24        Artículo 18
# 34        Artículo 28
# 43        Artículo 37
# 88    Artículo Cuarto
# Name: parent, dtype: object
# ---------
# ¿Cuánto tiempo durará en su cargo el Rector General?
# 25    Artículo 19
# 28    Artículo 22
# 50    Artículo 43
# 51    Artículo 44
# 26    Artículo 20
# Name: parent, dtype: object
# ---------
# ¿Qué se requiere para ser candidato a Rector General?
# 26    Artículo 20
# 25    Artículo 19
# 28    Artículo 22
# 24    Artículo 18
# 31    Artículo 25
# Name: parent, dtype: object
# ---------
# ¿Cuántos años de experiencia académica se requieren para ser candidato a Rector General?
# 26    Artículo 20
# 25    Artículo 19
# 46    Artículo 40
# 27    Artículo 21
# 24    Artículo 18
# Name: parent, dtype: object
# ---------
# ¿Quién suple al Rector General en ausencias que no excedan los tres meses?
# 25    Artículo 19
# 28    Artículo 22
# 50    Artículo 43
# 46    Artículo 40
# 24    Artículo 18
# Name: parent, dtype: object
# ---------
# ¿Cómo se integran los Consejos Universitarios de Campus?
# 29         Artículo 23
# 83    ARTÍCULO SÉPTIMO
# 30         Artículo 24
# 81     ARTÍCULO QUINTO
# 19         Artículo 13
# Name: parent, dtype: object
# ---------
# ¿A quíen corresponde conocer y aprobar el Plan de Desarrollo del Campus?
# 30        Artículo 24
# 32        Artículo 26
# 13         Artículo 7
# 31        Artículo 25
# 81    ARTÍCULO QUINTO
# Name: parent, dtype: object
# ---------
# ¿Quién es la autoridad ejecutiva del Campus?
# 31        Artículo 25
# 19        Artículo 13
# 81    ARTÍCULO QUINTO
# 29        Artículo 23
# 32        Artículo 26
# Name: parent, dtype: object
# ---------
# ¿Cuánto tiempo durará en su cargo el Rector de Campus?
# 25    Artículo 19
# 31    Artículo 25
# 32    Artículo 26
# 50    Artículo 43
# 28    Artículo 22
# Name: parent, dtype: object
# ---------
# ¿Qué requisitos deberá cumplir el Rector de Campus?
# 31    Artículo 25
# 32    Artículo 26
# 28    Artículo 22
# 25    Artículo 19
# 30    Artículo 24
# Name: parent, dtype: object
# ---------
# ¿Quién suple al Rector de Campus en ausencias que no excedan los tres meses?
# 31    Artículo 25
# 30    Artículo 24
# 32    Artículo 26
# 25    Artículo 19
# 28    Artículo 22
# Name: parent, dtype: object
# ---------
# ¿Quién es el encargado de gestionar los recursos del Campus?
# 30    Artículo 24
# 32    Artículo 26
# 61    Artículo 54
# 31    Artículo 25
# 19    Artículo 13
# Name: parent, dtype: object
# ---------
# ¿Quiénes integran los Consejos Divisionales?
# 33         Artículo 27
# 34         Artículo 28
# 83    ARTÍCULO SÉPTIMO
# 36         Artículo 30
# 29         Artículo 23
# Name: parent, dtype: object
# ---------
# ¿Quién es la autoridad ejecutiva de la división?
# 36         Artículo 30
# 35         Artículo 29
# 34         Artículo 28
# 78    ARTÍCULO SEGUNDO
# 33         Artículo 27
# Name: parent, dtype: object
# ---------
# ¿A quién le corresponde ejecutar los acuerdos del Consejo Divisional?
# 33         Artículo 27
# 36         Artículo 30
# 34         Artículo 28
# 83    ARTÍCULO SÉPTIMO
# 24         Artículo 18
# Name: parent, dtype: object
# ---------
# ¿A quién le correspone convocar al Consejo Divisional y presidir sus sesiones?
# 33         Artículo 27
# 34         Artículo 28
# 83    ARTÍCULO SÉPTIMO
# 36         Artículo 30
# 24         Artículo 18
# Name: parent, dtype: object
# ---------
# ¿Quién designa al Director del Departamento?
# 37    Artículo 31
# 44    Artículo 38
# 35    Artículo 29
# 38    Artículo 32
# 41    Artículo 35
# Name: parent, dtype: object
# ---------
# ¿Qué se requiere para ser Director de Departamento?
# 37    Artículo 31
# 38    Artículo 32
# 35    Artículo 29
# 44    Artículo 38
# 41    Artículo 35
# Name: parent, dtype: object
# ---------
# ¿A quién corresponde asegurar el cumplimiento de los proyectos del Departamento?
# 38                   Artículo 32
# 82                ARTÍCULO SEXTO
# 2     II. Trabajo de la comisión
# 83              ARTÍCULO SÉPTIMO
# 13                    Artículo 7
# Name: parent, dtype: object
# ---------
# ¿A quién corresponde evaluar las funciones del Departamento?
# 38        Artículo 32
# 53        Artículo 46
# 84    ARTÍCULO OCTAVO
# 43        Artículo 37
# 11         Artículo 5
# Name: parent, dtype: object
# ---------
# ¿Quiénes integran el Consejo Académico del Nivel Medio superior?
# 39    Artículo 33
# 18    Artículo 12
# 20    Artículo 14
# 41    Artículo 35
# 42    Artículo 36
# Name: parent, dtype: object
# ---------
# ¿A quíen corresponde aprobar el Plan de Desarrollo del Colegio de Nivel Medio Superior?
# 41    Artículo 35
# 42    Artículo 36
# 40    Artículo 34
# 20    Artículo 14
# 13     Artículo 7
# Name: parent, dtype: object
# ---------
# ¿Quién es la autoridad ejecutiva del Colegio del Nivel Medio Superior?
# 20    Artículo 14
# 41    Artículo 35
# 39    Artículo 33
# 42    Artículo 36
# 18    Artículo 12
# Name: parent, dtype: object
# ---------
# ¿Qué requisitos deberá cumplir el Director del Colegio del Nivel Medio Superior?
# 41    Artículo 35
# 39    Artículo 33
# 44    Artículo 38
# 20    Artículo 14
# 42    Artículo 36
# Name: parent, dtype: object
# ---------
# ¿A quién corresponde designar y, en su caso, remover a quienes dirijan las Escuelas de Nivel Medio Superior?
# 20    Artículo 14
# 42    Artículo 36
# 44    Artículo 38
# 40    Artículo 34
# 41    Artículo 35
# Name: parent, dtype: object
# ---------
# ¿Qué decisiones se toman en las Académias?
# 43                   Artículo 37
# 47                   Artículo 41
# 59                   Artículo 52
# 14                    Artículo 8
# 2     II. Trabajo de la comisión
# Name: parent, dtype: object
# ---------
# Name: parent, dtype: object
# ---------
# ¿Con cuántos días habiles de anticipación deberá ser emitida la consulta de la terna para designar al titular del Órgano Interno de Control?
# 71          Artículo 61 Bis
# 88          Artículo Cuarto
# 89          Artículo Quinto
# 74    Artículo 61 Quinquies
# 73       Artículo 61 Quáter
# Name: parent, dtype: object
# ---------
# ¿Que sucede en caso de falta absoluta, renuncia o remoción del titular del Órgano Interno de Control?
# 72          Artículo 61 Ter
# 71          Artículo 61 Bis
# 74    Artículo 61 Quinquies
# 73       Artículo 61 Quáter
# 88          Artículo Cuarto
# Name: parent, dtype: object
# ---------
# ¿Que no podrá hacer quien tenga la titularidad del Órgano Interno de Control?
# 71          Artículo 61 Bis
# 73       Artículo 61 Quáter
# 89          Artículo Quinto
# 88          Artículo Cuarto
# 74    Artículo 61 Quinquies
# Name: parent, dtype: object
# ---------
# ¿Cuáles son las causas graves de rmoción del titular del Órgano Interno de Control?
# 74    Artículo 61 Quinquies
# 89          Artículo Quinto
# 71          Artículo 61 Bis
# 88          Artículo Cuarto
# 87         Artículo Tercero
# Name: parent, dtype: object
# ---------
# ¿Quién es el encargado de aplicar las sanciones correspondientes al personal administrativo de la Universidad?
# 14     Artículo 8
# 59    Artículo 52
# 75    Artículo 62
# 46    Artículo 40
# 50    Artículo 43
# Name: parent, dtype: object
# ---------
# ¿Que sucederá con el personal académico y los alumnos que infrinjan el marco normativo interno de la Universidad?
# 76    Artículo 63
# 14     Artículo 8
# 59    Artículo 52
# 50    Artículo 43
# 63    Artículo 56
# Name: parent, dtype: object
# ---------
# ¿Cuándo entrará en vigor el presente Decreto?
# 77    ARTÍCULO PRIMERO
# 91      Artículo Único
# 89     Artículo Quinto
# 85    Artículo Primero
# 88     Artículo Cuarto
# Name: parent, dtype: object
# ---------
# ¿Cuándo se publicó el Decreto número 279, emitido por la Quincuagésima Quinta Legislatura del Estado de Guanajuato?
# 78                                ARTÍCULO SEGUNDO
# 85                                Artículo Primero
# 91                                  Artículo Único
# 0     LEY ORGÁNICA DE LA UNIVERSIDAD DE GUANAJUATO
# 84                                 ARTÍCULO OCTAVO
# Name: parent, dtype: object
# ---------
# ¿De acuerdo a este decreto, qué rango adquiere el Rector de la Universidad de Guanajuato?
# 25        Artículo 19
# 50        Artículo 43
# 90     Artículo Sexto
# 80    ARTÍCULO CUARTO
# 84    ARTÍCULO OCTAVO
# Name: parent, dtype: object
# ---------
# ¿Cuánto tiempo tiene el Consejo Universitario para aprobar la composición académica de los Campus, Divisiones y Departamentos?
# 81     ARTÍCULO QUINTO
# 19         Artículo 13
# 83    ARTÍCULO SÉPTIMO
# 29         Artículo 23
# 58         Artículo 51
# Name: parent, dtype: object
# ---------
# ¿A quienes convocarán los Directores de Departamento para elegir a sus representantes ante el Consejo Divisional?
# 33         Artículo 27
# 37         Artículo 31
# 83    ARTÍCULO SÉPTIMO
# 34         Artículo 28
# 36         Artículo 30
# Name: parent, dtype: object
# ---------
# % of presence in top 5: 0.7368421052631579
